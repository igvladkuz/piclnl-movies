# %%
import pandas as pd
import matplotlib.pyplot as plt 
import os

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

PATH_PREFIX = ""
DATA_DIR = "data"

# %%
mv = pd.read_parquet(os.path.join(PATH_PREFIX, DATA_DIR, 'movies.parquet'))
mv.head()
# Out:
#                         title  \
# 0       El perro que no calla
# 1                Hoogtijdagen
# 2  Oliver Sacks: His Own Life
# 3                      Lapsis
# 4                       Sweat
#
#                                          description  \
# 0  Sebastián is een dertiger met een hond en een ...
# 1  Op het schiereiland Kola zijn de sporen van de...
# 2  Een paar weken na het afronden van zijn memoir...
# 3  De komst van een nieuwe vorm van bankieren zet...
# 4  Wanneer fitnesscoach en influencer Sylwia Zaja...
#
#                                 pa       te_zien_tot  \
# 0                  Alle leeftijden  20 december 2021
# 1                  Alle leeftijden  20 december 2021
# 2                  Alle leeftijden  13 december 2021
# 3  Mogelijk schadelijk tot 16 jaar  13 december 2021
# 4  Mogelijk schadelijk tot 16 jaar  13 december 2021
#
#                              genre              land      taal ondertitels  \
# 0                            drama        Argentinië   Spaans   Nederlands
# 1                     documentaire         Nederland  Russisch  Nederlands
# 2                     documentaire  Verenigde Staten    Engels  Nederlands
# 3  drama, mysterie, sciencefiction  Verenigde Staten    Engels  Nederlands
# 4                            drama             Polen     Pools  Nederlands
#
#    speelduur         regisseur                       distributeur  min_age  \
# 0   73  min.          Ana Katz                     Periscoop Film        0
# 1    90 min.  Ben van Lieshout                Cinema Delicatessen        0
# 2   94  min.         Ric Burns                     Periscoop Film        0
# 3  108  min.       Noah Hutton                       De Filmfreak       16
# 4   105 min.   Magnus von Horn  Imagine Filmdistributie Nederland       16
#
#    duration_min     director_norm                  title_norm primary_genre
# 0            73          ana katz       el perro que no calla         drama
# 1            90  ben van lieshout                hoogtijdagen  documentaire
# 2            94         ric burns  oliver sacks: his own life  documentaire
# 3           108       noah hutton                      lapsis         drama
# 4           105   magnus von horn                       sweat         drama

# %%
# get stopwords from this project https://github.com/Alir3z4/python-stop-words
# otherwise proceed without
def get_stopwords(file_name):
    try:
        with open(os.path.join(PATH_PREFIX,"data",file_name)) as f:
            stopwords_nl_str = f.read()

        return stopwords_nl_str.split("\n")
    except:
        print("No stopwords file found. Proceeding without stopwords")
        return []

stopwords_nl = get_stopwords("dutch.txt")

# %%
mv_desc=mv[['description']]
mv_desc.head()
# Out:
#                                          description
# 0  Sebastián is een dertiger met een hond en een ...
# 1  Op het schiereiland Kola zijn de sporen van de...
# 2  Een paar weken na het afronden van zijn memoir...
# 3  De komst van een nieuwe vorm van bankieren zet...
# 4  Wanneer fitnesscoach en influencer Sylwia Zaja...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf  = TfidfVectorizer(stop_words=stopwords_nl)#ToDo remove dutch stop-words passing them as stop_words
tfidf_matrix = tfidf.fit_transform(mv.description)

# %%
# see the vocabulary
#print(tfidf.get_feature_names())

# %%
# description conwerted to TFIDF features
tfidf_matrix
# Out:
# <93x3135 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5151 stored elements in Compressed Sparse Row format>

# %%
# let's take a film and find similar films using cosine distance between their vectors
name = 'Wong Kar Wai'
mv[mv.regisseur.str.contains(name)]
# Out:
#                    title                                        description  \
# 9   In the Mood for Love  Tony Leung en Maggie Cheung ontmoeten elkaar i...
# 10                  2046  Na het succes van In the Mood for Love (2000) ...
# 11     Chungking Express  Regisseur Wong Kar Wai smeedt het grotestadsle...
# 12         Fallen Angels  Ook het vervolg op Chungking Express is een st...
# 13        Happy Together  Hongkong-supersterren Tony Leung en Leslie Che...
# 14              The Hand  Een mysterieuze courtisane verleent haar nieuw...
#
#                                  pa      te_zien_tot  \
# 9                   Alle leeftijden  6 december 2021
# 10  Mogelijk schadelijk tot 12 jaar  6 december 2021
# 11  Mogelijk schadelijk tot 12 jaar  6 december 2021
# 12  Mogelijk schadelijk tot 16 jaar  6 december 2021
# 13  Mogelijk schadelijk tot 12 jaar  6 december 2021
# 14                  Alle leeftijden  6 december 2021
#
#                                genre       land                          taal  \
# 9                   drama, romantiek   Hongkong                     Kantonees
# 10  drama, romantiek, sciencefiction  Hong Kong  Kantonees, Japans, Mandarijn
# 11             crime, drama, komedie   Hongkong                     Kantonees
# 12             crime, drama, komedie   Hongkong                     Kantonees
# 13                  drama, romantiek  Hong Kong  Mandarijn, Spaans, Kantonees
# 14                  drama, romantiek  Hong Kong                     Mandarijn
#
#    ondertitels speelduur     regisseur       distributeur  min_age  \
# 9   Nederlands   98 min.  Wong Kar Wai  Cinéart Nederland        0
# 10  Nederlands  129 min.  Wong Kar Wai  Cinéart Nederland       12
# 11  Nederlands  102 min.  Wong Kar Wai  Cinéart Nederland       12
# 12  Nederlands   99 min.  Wong Kar Wai  Cinéart Nederland       16
# 13  Nederlands   96 min.  Wong Kar Wai  Cinéart Nederland       12
# 14  Nederlands   56 min.  Wong Kar Wai  Cinéart Nederland        0
#
#     duration_min director_norm            title_norm primary_genre
# 9             98  wong kar wai  in the mood for love         drama
# 10           129  wong kar wai                  2046         drama
# 11           102  wong kar wai     chungking express         crime
# 12            99  wong kar wai         fallen angels         crime
# 13            96  wong kar wai        happy together         drama
# 14            56  wong kar wai              the hand         drama

# %%
# let's take the first WKW film:
my_film = mv[mv.regisseur.str.contains(name)][:1]
display(my_film)
my_film_index  =my_film.index
# Out:
#                   title                                        description  \
# 9  In the Mood for Love  Tony Leung en Maggie Cheung ontmoeten elkaar i...
#
#                 pa      te_zien_tot             genre      land       taal  \
# 9  Alle leeftijden  6 december 2021  drama, romantiek  Hongkong  Kantonees
#
#   ondertitels speelduur     regisseur       distributeur  min_age  \
# 9  Nederlands   98 min.  Wong Kar Wai  Cinéart Nederland        0
#
#    duration_min director_norm            title_norm primary_genre
# 9            98  wong kar wai  in the mood for love         drama

# %%
my_film_vector = tfidf_matrix[my_film_index]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
distances = cosine_similarity(my_film_vector, tfidf_matrix)
distances.T.shape

# %%
# Top 5 films recommended based on the choice of my_film
mv['similarity'] = distances.T
mv.sort_values('similarity', ascending=False).head(5)
# Out:
#                    title                                        description  \
# 9   In the Mood for Love  Tony Leung en Maggie Cheung ontmoeten elkaar i...
# 10                  2046  Na het succes van In the Mood for Love (2000) ...
# 13        Happy Together  Hongkong-supersterren Tony Leung en Leslie Che...
# 45   Flowers of Shanghai  Filmmaker Hou Hsiao-hsien zoomt in op het emot...
# 11     Chungking Express  Regisseur Wong Kar Wai smeedt het grotestadsle...
#
#                                  pa      te_zien_tot  \
# 9                   Alle leeftijden  6 december 2021
# 10  Mogelijk schadelijk tot 12 jaar  6 december 2021
# 13  Mogelijk schadelijk tot 12 jaar  6 december 2021
# 45  Mogelijk schadelijk tot 16 jaar  8 november 2021
# 11  Mogelijk schadelijk tot 12 jaar  6 december 2021
#
#                                genre             land  \
# 9                   drama, romantiek         Hongkong
# 10  drama, romantiek, sciencefiction        Hong Kong
# 13                  drama, romantiek        Hong Kong
# 45                             drama  Taiwan en Japan
# 11             crime, drama, komedie         Hongkong
#
#                             taal ondertitels speelduur        regisseur  \
# 9                      Kantonees  Nederlands   98 min.     Wong Kar Wai
# 10  Kantonees, Japans, Mandarijn  Nederlands  129 min.     Wong Kar Wai
# 13  Mandarijn, Spaans, Kantonees  Nederlands   96 min.     Wong Kar Wai
# 45                     Kantonees  Nederlands  113 min.  Hou Hsiao-hsien
# 11                     Kantonees  Nederlands  102 min.     Wong Kar Wai
#
#          distributeur  min_age  duration_min    director_norm  \
# 9   Cinéart Nederland        0            98     wong kar wai
# 10  Cinéart Nederland       12           129     wong kar wai
# 13  Cinéart Nederland       12            96     wong kar wai
# 45     EYE Filmmuseum       16           113  hou hsiao-hsien
# 11  Cinéart Nederland       12           102     wong kar wai
#
#               title_norm primary_genre  similarity
# 9   in the mood for love         drama    1.000000
# 10                  2046         drama    0.193363
# 13        happy together         drama    0.137076
# 45   flowers of shanghai         drama    0.080232
# 11     chungking express         crime    0.078249
